# %%
import pandas as pd

# %%
data = pd.read_csv('survey_results_public.csv')
data2 = pd.read_csv('survey_results_schema.csv')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(3)
# Out:
#    Respondent Hobby OpenSource         Country Student          Employment  \
# 0           1   Yes         No           Kenya      No  Employed part-time
# 1           3   Yes        Yes  United Kingdom      No  Employed full-time
# 2           4   Yes        Yes   United States      No  Employed full-time
#
#                             FormalEducation  \
# 0  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                          Associate degree
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
#
#                                              DevType  ...  \
# 0                               Full-stack developer  ...
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
data.shape
# Out:
# (98855, 129)

# %%
data[data.].value_counts()
# Out:
#   File "<ipython-input-6-7c645eb06d32>", line 1
#     data[data.].value_counts()
#               ^
# SyntaxError: invalid syntax

# %%
data['Hobby'].value_counts()

# %%
data.loc[0:2, 'Hobby':'Employment']

# %% [markdown]
# This is pandas tutorial part (3) by corey how set, reset, and use index.

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %% [markdown]
# df

# %%
df['email']

# %% [markdown]
# what about if we want email address set  as index

# %%
df.set_index('email')

# %%
df   # pandas does not want to modify data unless we told to do so. we set the email as index , but take a effect.

# %%
df.set_index('email', inplace = True) # inplace equal true modify that data by setting email as index.

# %%
df

# %%
df.index

# %%
df.loc['CoreyMSchafer@gmail.com']

# %%
df.iloc[0]

# %%
df.reset_index(inplace =True) # reseting the index to original

# %%
df

# %%
data = pd.read_csv('survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
data

# %%
data2 = pd.read_csv('survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
data2 # checking what hobbiest mean.

# %%
data2.loc['MilitaryUS','QuestionText'] # searching rows by column level.

# %%
data2.sort_index(ascending = False)

# %% [markdown]
# Python Pandas Tutorial (Part 4): Filtering - Using Conditionals to Filter Rows and Columns

# %%
filt_last = (df['last']=='Schafer') | ( df['first']=='John') #this is filter mask.

# %%
df.loc[filt_last,]

# %%
data = pd.read_csv('survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
data.columns

# %%
filt= (data['Country']=='Kenya')& (data['Employment']=='Employed full-time')

# %%
data.loc[filt,['StackOverflowConsiderMember', 'HypotheticalTools2']]

# %%
data2.columns

# %%
df

# %%
df.columns = [x.lower() for x  in df.columns]

# %%
df

# %%
df.columns = df.columns.str.replace('_' ,  '')

# %%
df

# %%
df.rename(columns = {'first':'first_name', 'last':'last_name'},inplace = True)

# %%
df.loc['last'] ='Doe'

# %%
df

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df

# %%
filt = (df['email']=='JohnDoe@email.com') # This bolean series , but when assign variable name filt and as funciton of the data

# %%
df[filt]['last']

# %%
df[filt, 'last']= 'Smith' # updating one row.

# %%
df.loc[filt, 'last']= 'Smith' # we add loc

# %%
df

# %%
df['email'] = df['email'].str.lower() # changing the email to lower case letter.

# %%
df

# %% [markdown]
# But, there is advanced way to do it. mean to update more than one row at the time.
# bellow are four  methods that assist us.
# apply
# map
# applymap
# replace

# %%
df['email'].apply(len)

# %%
def update_email(email):  #defining a function
    return email.upper()

# %%
df['email'] = df['email'].apply(update_email) # apply that function here

# %%
df

# %%
df['email'] = df['email'].apply(lambda x: x.lower())   # let's use lamda function return to lower case

# %%
df

# %%
df['email'].apply(len)

# %%
df.applymap(len) # this give us lenth of our column values.

# %%
df.applymap(str.lower) # change to lower case in our entire data value

# %%
df['first'].map({'corey': 'chris', 'jame': 'Mary'}) # substitution

# %%
df['first'].replace({'corey': 'chris', 'jame': 'Mary'})

# %%
data = pd.read_csv('survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
data

# %%
data.rename(columns= {'YearsCoding':'coding_exprience'}, inplace=True)

# %%
data['Hobby' ] = data['Hobby'].map({'Yes':True, 'No':False}) # this does not have inplace so we have to asign.
# if we have more than yes or no , it is good idea to use replace instead of map.

# %%
data

# %% [markdown]
# Python Pandas Tutorial (Part 6): Add/Remove Rows and Columns From DataFrames

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df

# %%
df['first'] + ' ' + df['last']

# %%
df['full_name'] = df['first'] + ' ' + df['last'] # adding an other column called full_name.

# %%
df

# %%
df.drop(columns = ['first', 'last'], inplace = True) # droping two columns

# %%
df

# %%
df['full_name'].str.split(' ', expand = True)

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand = True) # one columns into two

# %%
df

# %% [markdown]
# So far we learn how to drop a columns and split into two.
# df.drop(columns = ['first', 'last'], inplace = True) # droping two columns
# df[['first', 'last']] = df['full_name'].str.split(' ', expand = True) # one columns into two

# %%
df

# %%
df.append({'first':'Tony'}, ignore_index=True) # we adding a name at first name columns

# %%
people = {
    "first": ["Tony", 'Steve'], 
    "last": ["Stark", 'Rogers'], 
    "email": ["Ironman@avenge.com", 'Capa@avenge.com']
}

# %%
df2 = pd.DataFrame(people)

# %%
df2

# %%
df.append(df2, ignore_index = True, sort = False)

# %%
df = df.append(df2, ignore_index = True, sort = False)

# %%
df

# %%
df.drop(index = 4, inp) # we drop the rows by specifying the index.

# %%
df

# %%
filt = (df['last'] =='Doe')

# %%
df.drop(index =df[filt].index) # droping more than one row by filtering first.

# %% [markdown]
# Part 7 tutorial sorting data.

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df

# %%
df.sort_values(by = 'last')

# %%
df.sort_values(by = ['last', 'first'], ascending = False)

# %%
data = pd.read_csv('survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
data.head()

# %%
data.sort_values(by = 'Country', inplace = True) # sort by country.

# %%
data['Country'].head(50)

# %%
data['ConvertedSalary'].median() # median is correct representation because it does not effect the oulier.

# %%
data.median()

# %%
data.describe()

# %%
data['ConvertedSalary'].count()

# %%
data['Hobby'].value_counts()

# %%
data

# %%
data['Country'].value_counts(normalize = True)

# %%
 country_grp = data.groupby(['Country']) # split up by country.
# we coud do following 
#filt = data['Country']=='United States'
#data.loc[filt] # we have do for every country.

# %%
country_grp.get_group('United States')
# Out:
#        Respondent Hobby OpenSource        Country         Student  \
# 2               4   Yes        Yes  United States              No
# 3               5    No         No  United States              No
# 6               9   Yes        Yes  United States              No
# 8              11   Yes        Yes  United States              No
# 16             26    No         No  United States  Yes, full-time
# ...           ...   ...        ...            ...             ...
# 98788      100432    No         No  United States              No
# 98803      100680   Yes         No  United States              No
# 98820      101006   Yes        Yes  United States             NaN
# 98847      101411    No         No  United States             NaN
# 98850      101513   Yes        Yes  United States             NaN
#
#                Employment                                    FormalEducation  \
# 2      Employed full-time                                   Associate degree
# ...

# %%
country_grp['ConvertedSalary'].agg(['median', 'mean']).loc['United States']
# Out:
# median    100000.000000
# mean      154413.128506
# Name: United States, dtype: float64

# %%
data.head(3)
# Out:
#    Respondent Hobby OpenSource         Country Student          Employment  \
# 0           1   Yes         No           Kenya      No  Employed part-time
# 1           3   Yes        Yes  United Kingdom      No  Employed full-time
# 2           4   Yes        Yes   United States      No  Employed full-time
#
#                             FormalEducation  \
# 0  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                          Associate degree
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
#
#                                              DevType       YearsCoding  \
# ...

# %%
country_grp['DevType'].apply(lambda x:x.str.contains('Database').sum())
# Out:
# Country
# Afghanistan                             14
# Albania                                 22
# Algeria                                 28
# Andorra                                  4
# Angola                                   4
#                                         ..
# Venezuela, Bolivarian Republic of...    25
# Viet Nam                                32
# Yemen                                    4
# Zambia                                   2
# Zimbabwe                                14
# Name: DevType, Length: 183, dtype: int64

# %%
 country_respondents = data['Country'].value_counts()

# %%
country_uses_database = country_grp['DevType'].apply(lambda x:x.str.contains('Database').sum())
country_uses_database
# Out:
# Country
# Afghanistan                             14
# Albania                                 22
# Algeria                                 28
# Andorra                                  4
# Angola                                   4
#                                         ..
# Venezuela, Bolivarian Republic of...    25
# Viet Nam                                32
# Yemen                                    4
# Zambia                                   2
# Zimbabwe                                14
# Name: DevType, Length: 183, dtype: int64

# %%
database_data = pd.concat([country_respondents, country_uses_database], axis = 'columns' , sort= False)

# %%
database_data
# Out:
#                  Country  DevType
# United States      20309     2745
# India              13721     1263
# Germany             6459      929
# United Kingdom      6221      951
# Canada              3393      457
# ...                  ...      ...
# Djibouti               1        0
# Nauru                  1        0
# Belize                 1        0
# San Marino             1        1
# Solomon Islands        1        0
#
# [183 rows x 2 columns]

# %%
database_data.rename(columns = {'Country':'numrespondent', 'DevType':'num_knows_sql'}, inplace=True)

# %%
database_data
# Out:
#                  numrespondent  num_knows_sql
# United States            20309           2745
# India                    13721           1263
# Germany                   6459            929
# United Kingdom            6221            951
# Canada                    3393            457
# ...                        ...            ...
# Djibouti                     1              0
# Nauru                        1              0
# Belize                       1              0
# San Marino                   1              1
# Solomon Islands              1              0
#
# [183 rows x 2 columns]

# %%
database_data['prc_knows_sql'] = (database_data['num_knows_sql']/database_data['numrespondent']) *100

# %%
database_data.head(50).max()
# Out:
# numrespondent    20309.000000
# num_knows_sql     2745.000000
# prc_knows_sql       22.380952
# dtype: float64

# %%
database_data.sort_values(by='prc_knows_sql', ascending = False, inplace = True )

# %%
database_data.head(50)
# Out:
#                                   numrespondent  num_knows_sql  prc_knows_sql
# Dominica                                      2              2     100.000000
# Lesotho                                       2              2     100.000000
# San Marino                                    1              1     100.000000
# Mali                                          1              1     100.000000
# Timor-Leste                                   1              1     100.000000
# Saint Lucia                                   1              1     100.000000
# Grenada                                       1              1     100.000000
# Mauritania                                    3              2      66.666667
# Swaziland                                     3              2      66.666667
# Barbados                                      4              2      50.000000
# Congo, Republic of the...                     6              3      50.000000
# ...

# %%
database_data.loc['United States']
# Out:
# numrespondent    20309.000000
# num_knows_sql     2745.000000
# prc_knows_sql       13.516175
# Name: United States, dtype: float64

# %% [markdown]
# #Python #Pandas
# Python Pandas Tutorial (Part 9): Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
import pandas as pd
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)
df.replace('NA', np.nan, inplace =True)
df.replace('Missing', np.nan, inplace = True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis = 'index', how = 'all', subset = ['last', 'email']) # drop if email or last is missing and replace with NAN.
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df['age'].mean() # because some values are string or int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     550     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 551     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     552
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: can only concatenate str (not "int") to str
#
# ...

# %%
df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# 46.75

# %% [markdown]
# Let's go back to stock over survery data

# %%
na_val = ['NA', 'MISSING']
data = pd.read_csv('survey_results_public.csv', index_col='Respondent', na_values = na_val)
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data['YearsCoding'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     550     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 551     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     552
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: can only concatenate str (not "int") to str
#
# ...

# %%
data['YearsCoding'].unique()
# Out:
# array([ 4., 31., 25., 14.,  7., 10.,  1., 16., 13., 22., nan])

# %%
data['YearsCoding'].replace('3-5 years', 4, inplace = True)
data['YearsCoding'].replace('30 or more years', 31, inplace = True)
data['YearsCoding'].replace('24-26 years', 25, inplace = True)
data['YearsCoding'].replace('18-20 years', 14, inplace = True)
data['YearsCoding'].replace('6-8 years', 7, inplace = True)
data['YearsCoding'].replace('9-11 years', 10, inplace = True)
data['YearsCoding'].replace('0-2 years', 1, inplace = True)
data['YearsCoding'].replace('15-17 years', 16, inplace = True)
data['YearsCoding'].replace('12-14 years', 13, inplace = True)
data['YearsCoding'].replace('21-23 years', 22, inplace = True)
data['YearsCoding'].replace('27-29 years', 22, inplace = True)

# %%
data['YearsCoding'] = data['YearsCoding'].astype(float)

# %%
data['YearsCoding'].mean()
# Out:
# 9.295572014706666
